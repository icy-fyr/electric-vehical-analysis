# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data= pd.read_csv("pmsm_temperature_data.csv")

# %%
data.head()
# Out:
#     ambient   coolant       u_d       u_q  motor_speed    torque       i_d  \
# 0 -0.752143 -1.118446  0.327935 -1.297858    -1.222428 -0.250182  1.029572
# 1 -0.771263 -1.117021  0.329665 -1.297686    -1.222429 -0.249133  1.029509
# 2 -0.782892 -1.116681  0.332771 -1.301822    -1.222428 -0.249431  1.029448
# 3 -0.780935 -1.116764  0.333700 -1.301852    -1.222430 -0.248636  1.032845
# 4 -0.774043 -1.116775  0.335206 -1.303118    -1.222429 -0.248701  1.031807
#
#         i_q        pm  stator_yoke  stator_tooth  stator_winding  profile_id
# 0 -0.245860 -2.522071    -1.831422     -2.066143       -2.018033           4
# 1 -0.245832 -2.522418    -1.830969     -2.064859       -2.017631           4
# 2 -0.245818 -2.522673    -1.830400     -2.064073       -2.017343           4
# 3 -0.246955 -2.521639    -1.830333     -2.063137       -2.017632           4
# 4 -0.246610 -2.521900    -1.830498     -2.062795       -2.018145           4

# %%
df = data[['u_d','u_q','i_d','i_q','motor_speed']]

# %%
print("shape of dataset")
print(df.shape)
print("columns in dataset")
print(df.columns)
print(df.info())
# Out:
# shape of dataset
# (998070, 5)
# columns in dataset
# Index(['u_d', 'u_q', 'i_d', 'i_q', 'motor_speed'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998070 entries, 0 to 998069
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   u_d          998070 non-null  float64
#  1   u_q          998070 non-null  float64
#  2   i_d          998070 non-null  float64
#  3   i_q          998070 non-null  float64
#  4   motor_speed  998070 non-null  float64
# dtypes: float64(5)
# memory usage: 38.1 MB
# None

# %%
fig2, ax2 = plt.subplots(figsize=(6,6))
sns.heatmap(df.corr(), center=0, cmap='Blues')
ax2.set_title('dependency')
# Out:
# Text(0.5, 1.0, 'dependency')

# %%
npd= nid*nud
npq=niq*nuq

# %%
dummy=pd.DataFrame(list(zip(npd, npq)),
               columns =['p_d','p_q'])

# %%
df['p_d']=dummy['p_d']
# Out:
# <ipython-input-9-40ff54818d91>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['p_d']=dummy['p_d']

# %%
df['p_q']=dummy['p_q']
# Out:
# <ipython-input-10-f357591e7be7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['p_q']=dummy['p_q']

# %%
df.head()
# Out:
#         u_d       u_q       i_d       i_q  motor_speed                    p_d  \
# 0  0.327935 -1.297858  1.029572 -0.245860    -1.222428     [0.33763303090848]
# 1  0.329665 -1.297686  1.029509 -0.245832    -1.222429      [0.3393928785832]
# 2  0.332771 -1.301822  1.029448 -0.245818    -1.222428     [0.34257085530055]
# 3  0.333700 -1.301852  1.032845 -0.246955    -1.222430  [0.34466023984551003]
# 4  0.335206 -1.303118  1.031807 -0.246610    -1.222429  [0.34586803394330995]
#
#                      p_q
# 0  [0.31909128388572505]
# 1  [0.31901326995081497]
# 2    [0.320011128541298]
# 3      [0.3214986002896]
# 4     [0.32136152601342]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998070 entries, 0 to 998069
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   u_d          998070 non-null  float64
#  1   u_q          998070 non-null  float64
#  2   i_d          998070 non-null  float64
#  3   i_q          998070 non-null  float64
#  4   motor_speed  998070 non-null  float64
#  5   p_d          998070 non-null  object
#  6   p_q          998070 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 45.7+ MB

# %%
ax = plt.gca()
df.plot( x = 'i_q' , y = 'motor_speed', ax = ax )
# Out:
# <AxesSubplot:xlabel='i_q'>

# %%
ax = plt.gca()
df.plot( x = 'i_d' , y = 'motor_speed', ax = ax )
# Out:
# <AxesSubplot:xlabel='i_d'>

# %%
ax = plt.gca()
df.plot( x = 'u_d' , y = 'motor_speed', ax = ax )
# Out:
# <AxesSubplot:xlabel='u_d'>

# %%
ax = plt.gca()
df.plot( x = 'u_q' , y = 'motor_speed', ax = ax )
# Out:
# <AxesSubplot:xlabel='u_q'>

# %%
ax = plt.gca()
df.plot( x = 'p_d' , y = 'motor_speed', ax = ax )
# Out:
# <AxesSubplot:xlabel='p_d'>

# %%
ax = plt.gca()
df.plot( x = 'p_q' , y = 'motor_speed', ax = ax )
# Out:
# <AxesSubplot:xlabel='p_q'>
